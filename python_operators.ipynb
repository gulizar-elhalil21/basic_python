# %% [markdown]
# ## operators in Python

# %%
#when we use the math we need to import the math library to use the math functions
import math
# to calculate the square root of a number we can use the sqrt() function from the math library
num = 16
result = math.sqrt(num)
print(result)
# Out:
# 4.0
